# %% [markdown]
# <a href="https://colab.research.google.com/github/Aisyaaswy/Pemrograman_Mesin/blob/main/jobsheet_1/tugas_praktikum_1/TG1_244107020109_Aisya_Aswy_Nur_Aidha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bagian 1**

# %%
# !pip install pyprep scipy wandb
# !pip install ishneholterlib wfdb
# !pip install pyecg --no-deps

# %% [markdown]
# Penjelasan kegunaan masing-masing library:
# 1. PyPREP: Digunakan untuk membersihkan data sinyal otak (EEG) dari gangguan atau noise secara otomatis sebelum dianalisis lebih lanjut.
# 2. Scipy: Menyediakan berbagai rumus matematika, statistik, dan algoritma komputasi sains untuk mengolah data numerik yang kompleks.
# 3. wandb (Weights & Biases): Berfungsi mencatat, memantau, dan visualisasi grafik eksperimen machine learning secara real-time agar mudah membandingkan performa model.
# 4. pyECG: Digunakan khusus untuk membaca, mengekstraksi fitur, dan mengolah data sinyal rekam jantung (EKG/ECG).
#
# Pada kode saya terdapat penambahan library ishneholterlib dan wfdb, serta opsi --no-deps pada pyecg. Penambahan ini dilakukan karena paket bawaan pyecg membutuhkan dependensi versi lama yang memicu error di Python versi terbaru pada Colab, sehingga dependensi pendukungnya diinstal secara terpisah agar seluruh pustaka dapat terpasang dengan lancar.

# %% [markdown]
# # **Bagian 2**
#
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
# - Penggunaan teknologi Deepfake untuk menyebarkan berita bohong (hoaks) atau penipuan berbasis identitas palsu.
# - Seseorang menggunakan kecerdasan buatan untuk mengubah wajah atau menirukan suara pejabat/tokoh terkenal dalam sebuah video. Video palsu ini kemudian dipakai untuk menipu masyarakat demi keuntungan pribadi atau merusak nama baik orang lain. Tindakan ini melanggar etika karena memanipulasi kebenaran dan melanggar hukum terkait privasi serta penipuan digital (UU ITE).
# - Referensi: [Kementrian Komunikasi dan Digital](https://www.komdigi.go.id/)
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
# - Tingginya konsumsi listrik dan pemborosan air pendingin pada pusat data (data center) AI.
# - Melatih model AI berukuran besar membutuhkan ribuan komputer canggih yang bekerja nonstop. Proses ini menyedot daya listrik yang sangat besar dan membutuhkan jutaan liter air hanya untuk mendinginkan mesin-mesin server tersebut, sehingga meningkatkan emisi karbon yang memperburuk pemanasan global.
# - Cara mengatasi:
#   1. Menggunakan sumber energi terbarukan (seperti panel surya atau tenaga angin) untuk mengoperasikan pusat data AI.
#   2. Mengembangkan model AI yang lebih efisien dan hemat daya (Green AI).
# - Pendapat pribadi: Kita sebaiknya membatasi penggunaan model AI yang terlalu kompleks jika tugas yang dikerjakan sederhana, agar tidak membuang-buang daya komputasi secara sia-sia.
# - Referensi: [MIT  Technology Review - The Carbon Footprint of AI Transformation](https://www.technologyreview.com/?utm_source)
